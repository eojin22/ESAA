# %% [markdown]
# <a href="https://colab.research.google.com/github/eojin22/ESAA/blob/main/YB_%EB%B3%B5%EC%8A%B5%EC%8A%A4%ED%84%B0%EB%94%942.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 회귀(regression)
# - 여러 개의 독립변수와 한 개의 종속변수 간의 상관관계를 모델링하는 기법을 통칭
# - 유형: 독립변수 개수에 따라 단일/다중 회귀, 회귀 계수의 결합에 따라 선형/비선형 회귀
# - 잔차: 실제 값과 회귀 모델의 차이에 따른 오류 값을 남은 오류 => 잔차 합이 최소가 되는 모델이 최적의 회귀모델

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### 편향-분산 트레이드오프(Bias-Variance Trade off)
#
# - 저편향/저분산: 예측 결과가 실제 결과에 매우 잘 근접하면서도 예측 변동이 크지 않고 특정 부분에 집중돼 있는 아주 뛰어난 성능을 보임
#
# - 저편향/고분산: 예측 결과가 실제 결과에 비교적 근접하지만, 예측 결과가 실 제 결과를 중심으로 꽤 넓은 부분에 분포
#
# - 고편향/저분산: 정확한 결과에서 벗어나면서도 예측이 특정 부분에 집중됨
#
# - 고편향/고분산: 정확한 예측 결과를 벗어나면서도 넓은 부분에 분포

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### 규제 선형 모델 - 릿지, 라쏘, 엘라스틱넷
#
# - L2규제: W의 제곱에 대해 페널티 부여(릿지 회귀)
# - L1규제: W의 절댓값에 대해 페널티 부여. 영향력이 크지 않은 회귀 계수 값을 0으로 변환(라쏘 회귀)

# %% [markdown]
# ### 릿지 회귀
# - Ridge 클래스의 주요 생성 파라미터: alpha = 릿지 회귀의 alpha L2 규제 계수에 해당
# - alpha값이 커질수록 회귀 계수 값을 작게 만듦(but, 회귀 계수를 0으로 만들지는 않음)
# ### 라쏘 회귀
# - W 절댓값에 페널티를 부여하는 L1 규제를 선형 회귀에 적용한 것
# - L1 규제는 불필요한 회귀 계수를 급격하게 감소시켜 0으로 만들고 제거
# - L1 규제는 적절한 피처만 회귀에 포함시키는 피처 선택의 특성을 가짐
# - Lasso 클래스의 주요 생성 파라미터: alpha = 라쏘 회귀의 alpha L1 규제 계수에 해당
#
# ### 엘라스틱넷 회귀
# - L2+L1규제
#
# - 라쏘회귀가 서로 상관관계가 높은 피처들의 경우 중요 피처만을 셀렉션하고 다른 피처들의 회귀 계수 0으로 만드는 성향 강함 -> 이를 완화하기 위해 L2규제 추가

# %% [markdown]
# ---

# %% [markdown]
# # 로지스틱 회귀
# - 선형 회귀 방식을 분류에 적용한 알고리즘
# - 분류에 사용
# - 선형 회귀와 차이: 시그모이드 함수 최적선을 찾고 이 함수의 반환 값을 확률로 간주해 확률에 따라 분류를 결정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### CART(Classification And Regression Trees)
# 분류뿐만 아니라 회귀도 가능하게 해주는 트리 생성 알고리즘

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # 차원 축소
# - 매우 많은 피처로 구성된 다차원 데이터 세트의 차원을 축소해 새로운 차원의 데이터 세트를 생성하는 것
#
# 1. 피처 선택
# - 특정 피처에 종속성이 강한 불필요한 피처는 아예 제거하고 데이터의 특징을 잘 나타내는 주요 피처만 선택
#
# 2. 피처(특성) 추출
# - 기존 피처를 저차원의 중요 피처로 압축해서 추출하는 것-> 기존 피처와는 완전히 다른 값
# - 피처를 함축적으로 더 잘 설명할 수 있는 또 다른 공간으로 매핑해 추출하는 것.기존 피처가 인지하기 어려웠던 잠재적인 요소를 추출하는 것을 의미

# %% [markdown]
# ### PCA
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # 군집화
#
# ### K평균
# - 군집 중심점이라는 특정한 임의의 지점을 선택해 해당 중심에 가장 가까운 포인트들을 선택하는 군집화 기법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 군집 평가(Cluster Evaluation)
#
# ### 실루엣 분석
#
# - 각 군집간 거리가 얼마나 효율적으로 분리돼있는지 나타냄
# - 효율적으로 잘 분리됐다는 것은 다른 군집과의 거리는 떨어져 있고 동일 군집끼리 데이터는 서로 가깝게 잘 뭉쳐있다는 의미
#   - **실루엣 계수(silhouette coefficient):** 해당 데이터가 같은 군집 내의 데이터와 얼마나 가깝게 군집화돼 있고, 다른 군집에 있는 데이터와는 얼마나 멀리 분리돼있는지 나타내는 지표

# %% [markdown]
# ---

# %% [markdown]
# # 평균 이동(Mean Shift)
#
# - K-평균과 비슷하게 군집 중심을 지속적으로 이동시키는 군집화 알고리즘
#
# - 평균 이동 -> 밀도가 가장 높은 곳으로 중심 이동
#
# - KDE(Kernel Density Estimation)로 PDF를 추정하고, 이 PDF가 가장 높은 지점(데이터가 가장 집중된 곳)을 군집 중심으로 결정.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
